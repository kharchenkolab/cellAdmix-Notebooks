# %%
suppressPackageStartupMessages({
    library(ggplot2)
    library(cowplot)
    library(devtools)
    library(dplyr)
    library(magrittr)
})

suppressMessages({
  load_all()
  load_arial_font()
})

# %%
p_gut <- CachePath('gut_cell_score_ratios2.rds') %>% readRDS()

# %%
p_brain <- CachePath('brain_cell_score_ratios2.rds') %>% readRDS()

# %%
p_bc <- CachePath('bc_cell_score_ratios2.rds') %>% readRDS()

# %%
p_panc <- CachePath('panc_cell_score_ratios2.rds') %>% readRDS()

# %%
p_oc <- CachePath('oc_cell_score_ratios2.rds') %>% readRDS()

# %%
plist_full <- unlist(list(p_oc,p_gut,p_bc,p_brain,p_panc),recursive = FALSE)

# %%
plt_width <- 14
plt_height <- 11
options(repr.plot.width = plt_width, repr.plot.height = plt_height, repr.plot.res = 200)

fig <- plot_grid(plotlist=plist_full,ncol=3,align='hv',rel_heights = c(1,.45,.85,.55,.55),scale=.95)
fig
# Out:
# Picking joint bandwidth of 0.0445
#
# Picking joint bandwidth of 0.0902
#
# Picking joint bandwidth of 0.0623
#
# Picking joint bandwidth of 0.0871
#
# Picking joint bandwidth of 0.0855
# plot without title

# %%
pdf(OutputPath("benchmark_cell_comparisons.pdf"), useDingbats=FALSE, width=plt_width, height=plt_height)
fig
dev.off()
# Out:
# png
#   2
